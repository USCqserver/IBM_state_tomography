# %%
from qiskit import IBMQ
IBMQ.disable_account() 

token0 = 'c59327488ff0575f9fcafd3f8d8ad627a1574fcf130508ac0314f08af78afc5cc5787acd7527140cb8aeacceaf4eaf82960785df5636991287d4f086db3b7229'
provider = IBMQ.enable_account(token0)

# %% [markdown]
# ## check job complete time

# %%
job_id = '60d6485b9cbb5780b2f34581'
backend = provider.backends
job = backend.retrieve_job(job_id)
job._time_per_step['COMPLETED']
# Out:
# '2021-06-25T21:43:23.445Z'

# %%
job
# Out:
# namespace(_backend=<IBMQRetiredBackend('ibmq_athens') from IBMQ(hub='ibm-q', group='open', project='main')>,
#           _api=<qiskit.providers.ibmq.api.clients.account.AccountClient at 0x7f85729b1e50>,
#           _job_id='60d6485b9cbb5780b2f34581',
#           _creation_date=datetime.datetime(2021, 6, 25, 21, 19, 23, 332000, tzinfo=tzutc()),
#           _api_status='COMPLETED',
#           _kind=<ApiJobKind.QOBJECT_STORAGE: 'q-object-external-storage'>,
#           _name=None,
#           _time_per_step={'CREATING': '2021-06-25T21:19:23.332Z',
#                           'CREATED': '2021-06-25T21:19:26.668Z',
#                           'VALIDATING': '2021-06-25T21:19:26.698Z',
#                           'VALIDATED': '2021-06-25T21:20:39.832Z',
#                           'QUEUED': '2021-06-25T21:20:39.996Z',
#                           'RUNNING': '2021-06-25T21:38:03.049Z',
#                           'COMPLETED': '2021-06-25T21:43:23.445Z'},
#           _result=None,
# ...

# %%
provider.backends.jobs(backend_name='ibmq_athens')[2].properties()
# Out:
# namespace(backend_name='ibmq_athens',
#           backend_version='1.3.21',
#           last_update_date=datetime.datetime(2021, 7, 1, 17, 1, 14, tzinfo=tzutc()),
#           general=[Nduv('2021-07-01T17:01:14Z', jq_01, GHz, 0.00167045114712927),
#                    Nduv('2021-07-01T17:01:14Z', zz_01, GHz, -3.802523473566748e-05),
#                    Nduv('2021-07-01T17:01:14Z', jq_12, GHz, 0.001715963318618043),
#                    Nduv('2021-07-01T17:01:14Z', zz_12, GHz, -6.739337717569015e-05),
#                    Nduv('2021-07-01T17:01:14Z', jq_23, GHz, 0.001419786134211377),
#                    Nduv('2021-07-01T17:01:14Z', zz_23, GHz, -4.029010458592919e-05),
#                    Nduv('2021-07-01T17:01:14Z', jq_34, GHz, 0.0014300376658986506),
#                    Nduv('2021-07-01T17:01:14Z', zz_34, GHz, -7.676209360402695e-05)],
#           qubits=[[Nduv('2021-07-01T14:41:47Z', T1, us, 75.24212195225269),
# ...

# %%
backend = provider.backend(backend_name='ibmqx5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-1aa072df8d0d> in <module>
# ----> 1 backend = provider.backend(backend_name='ibmqx5')
#
# AttributeError: 'AccountProvider' object has no attribute 'backend'

# %%
backend.properties()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-e47e190b06c2> in <module>
# ----> 1 backend.properties()
#
# AttributeError: 'list' object has no attribute 'properties'

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 3.555555555555556e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-5-9b35b1d1e556> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ...

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_armonk')
prop=backend.properties()
for i in range(0,1):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 4.9777777777777776e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-6-0a345a4881a2> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ...

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmqx2')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_santiago')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_vigo')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_ourense')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
#ibmq_valencia
backends = provider.backends()

backend = provider.get_backend('ibmq_valencia')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
