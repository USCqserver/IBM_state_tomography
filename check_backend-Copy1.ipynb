# %%
from qiskit import IBMQ
# IBMQ.disable_account() 

token0 = '316cca1ff42067b9901b6a9e90ca76496e76b4a73139954176c6fe31a45572fcd37089924cbe5c41edb96a9b4c0e92e44451ed350e2a7e45dc809d26cd752eed'
provider = IBMQ.enable_account(token0)
# Out:
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/validation/fields/custom.py:76: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   numpy.integer, numpy.float,
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:111: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   z = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:112: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:111: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   z = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:112: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:111: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   z = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:112: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:111: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   z = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:112: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros(len(label), dtype=np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)
# /home/haimeng/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/quantum_info/operators/pauli.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   arr = np.asarray(arr).astype(np.bool)

# %% [markdown]
# ## check job complete time

# %%
job_id = '60d6485b9cbb5780b2f34581'
backend = provider.backends
job = backend.retrieve_job(job_id)
job._time_per_step['COMPLETED']
# Out:
# '2021-06-25T21:43:23.445Z'

# %%
job
# Out:
# namespace(_backend=<IBMQRetiredBackend('ibmq_athens') from IBMQ(hub='ibm-q', group='open', project='main')>,
#           _api=<qiskit.providers.ibmq.api.clients.account.AccountClient at 0x7f85729b1e50>,
#           _job_id='60d6485b9cbb5780b2f34581',
#           _creation_date=datetime.datetime(2021, 6, 25, 21, 19, 23, 332000, tzinfo=tzutc()),
#           _api_status='COMPLETED',
#           _kind=<ApiJobKind.QOBJECT_STORAGE: 'q-object-external-storage'>,
#           _name=None,
#           _time_per_step={'CREATING': '2021-06-25T21:19:23.332Z',
#                           'CREATED': '2021-06-25T21:19:26.668Z',
#                           'VALIDATING': '2021-06-25T21:19:26.698Z',
#                           'VALIDATED': '2021-06-25T21:20:39.832Z',
#                           'QUEUED': '2021-06-25T21:20:39.996Z',
#                           'RUNNING': '2021-06-25T21:38:03.049Z',
#                           'COMPLETED': '2021-06-25T21:43:23.445Z'},
#           _result=None,
#           _qobj=None,
#           _error=None,
#           _tags=[],
#           _run_mode='fairshare',
#           _status=<JobStatus.DONE: 'job has successfully run'>,
#           _queue_info=None,
#           _use_object_storage=True,
#           _backend_info={'id': '5e7ca123ef0935c3e8d138b7',
#                          'name': 'ibmq_athens'},
#           object_storage_info={},
#           deleted=False,
#           allow_object_storage=True,
#           summary_data={'size': {'input': 24254690, 'output': 27932},
#                         'success': True,
#                         'summary': {'num_circuits': 74,
#                          'gates_executed': 596570,
#                          'max_qubits_used': 5,
#                          'qobj_config': {'cost': 188.20228571428572,
#                           'shots': 8192,
#                           'memory_slots': 5,
#                           'type': 'QASM',
#                           'n_qubits': 5},
#                          'partial_validation': False},
#                         'resultTime': 319.95680615492165},
#           hub_info={'hub': {'name': 'ibm-q'},
#                     'group': {'name': 'open'},
#                     'project': {'name': 'main'}},
#           end_date='2021-06-25T21:43:23.168Z',
#           cost=188.20228571428572,
#           share_level='none',
#           user_id='5dd1f42ce9ff2500185fe478',
#           live_data_enabled=False,
#           created_by='local',
#           client_info={'name': 'ibmqprovider', 'version': '0.7.0'},
#           _cancelled=False,
#           _job_error_msg=None)

# %%
provider.backends.jobs(backend_name='ibmq_athens')[0].properties()
# Out:
# namespace(backend_name='ibmq_athens',
#           backend_version='1.3.6',
#           last_update_date=datetime.datetime(2021, 1, 15, 0, 39, 29, tzinfo=tzutc()),
#           general=[Nduv('2021-01-15T00:39:29Z', jq_12, GHz, 0.001715963318618043),
#                    Nduv('2021-01-15T00:39:29Z', zz_12, GHz, -6.739337717569015e-05),
#                    Nduv('2021-01-15T00:39:29Z', jq_34, GHz, 0.0014300376658986506),
#                    Nduv('2021-01-15T00:39:29Z', zz_34, GHz, -7.676209360402695e-05),
#                    Nduv('2021-01-15T00:39:29Z', jq_01, GHz, 0.00167045114712927),
#                    Nduv('2021-01-15T00:39:29Z', zz_01, GHz, -3.802523473566748e-05),
#                    Nduv('2021-01-15T00:39:29Z', jq_23, GHz, 0.001419786134211377),
#                    Nduv('2021-01-15T00:39:29Z', zz_23, GHz, -4.029010458592919e-05)],
#           qubits=[[Nduv('2021-01-14T05:24:47Z', T1, us, 69.956748822553),
#                    Nduv('2021-01-14T05:25:53Z', T2, us, 124.0954622256197),
#                    Nduv('2021-01-15T00:39:29Z', frequency, GHz, 5.175370551168443),
#                    Nduv('2021-01-15T00:39:29Z', anharmonicity, GHz, -0.33610237055834047),
#                    Nduv('2021-01-14T05:23:45Z', readout_error, , 0.010599999999999943),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas0_prep1, , 0.013599999999999945),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas1_prep0, , 0.0076),
#                    Nduv('2021-01-14T05:23:45Z', readout_length, ns, 3352.8888888888887)],
#                   [Nduv('2021-01-14T05:24:47Z', T1, us, 60.359788919191814),
#                    Nduv('2021-01-14T05:27:09Z', T2, us, 91.09046874520749),
#                    Nduv('2021-01-15T00:39:29Z', frequency, GHz, 5.267221087060701),
#                    Nduv('2021-01-15T00:39:29Z', anharmonicity, GHz, -0.33254504412181485),
#                    Nduv('2021-01-14T05:23:45Z', readout_error, , 0.011200000000000099),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas0_prep1, , 0.015800000000000036),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas1_prep0, , 0.0066),
#                    Nduv('2021-01-14T05:23:45Z', readout_length, ns, 3352.8888888888887)],
#                   [Nduv('2021-01-13T05:10:56Z', T1, us, 129.17029316574488),
#                    Nduv('2021-01-14T05:25:53Z', T2, us, 127.5411538956816),
#                    Nduv('2021-01-15T00:39:29Z', frequency, GHz, 5.052377908692426),
#                    Nduv('2021-01-15T00:39:29Z', anharmonicity, GHz, -0.3370771771901723),
#                    Nduv('2021-01-14T05:23:45Z', readout_error, , 0.027700000000000058),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas0_prep1, , 0.04200000000000004),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas1_prep0, , 0.0134),
#                    Nduv('2021-01-14T05:23:45Z', readout_length, ns, 3352.8888888888887)],
#                   [Nduv('2021-01-14T05:24:47Z', T1, us, 118.12077036952732),
#                    Nduv('2021-01-13T05:13:14Z', T2, us, 25.07546969390801),
#                    Nduv('2021-01-15T00:39:29Z', frequency, GHz, 4.855992402683682),
#                    Nduv('2021-01-15T00:39:29Z', anharmonicity, GHz, -0.32483596191153774),
#                    Nduv('2021-01-14T05:23:45Z', readout_error, , 0.1481),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas0_prep1, , 0.16759999999999997),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas1_prep0, , 0.1286),
#                    Nduv('2021-01-14T05:23:45Z', readout_length, ns, 3352.8888888888887)],
#                   [Nduv('2021-01-14T05:24:47Z', T1, us, 68.02993923909345),
#                    Nduv('2021-01-14T05:25:53Z', T2, us, 141.49854564701667),
#                    Nduv('2021-01-15T00:39:29Z', frequency, GHz, 5.1185551639727205),
#                    Nduv('2021-01-15T00:39:29Z', anharmonicity, GHz, -0.3361334185218728),
#                    Nduv('2021-01-14T05:23:45Z', readout_error, , 0.019200000000000106),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas0_prep1, , 0.027800000000000047),
#                    Nduv('2021-01-14T05:23:45Z', prob_meas1_prep0, , 0.0106),
#                    Nduv('2021-01-14T05:23:45Z', readout_length, ns, 3352.8888888888887)]],
#           gates=[namespace(qubits=[0],
#                            gate='id',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.00034156839459650943),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='id0'),
#                  namespace(qubits=[1],
#                            gate='id',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0005482093355872214),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='id1'),
#                  namespace(qubits=[2],
#                            gate='id',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0002868519954136414),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='id2'),
#                  namespace(qubits=[3],
#                            gate='id',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0022604510006537376),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='id3'),
#                  namespace(qubits=[4],
#                            gate='id',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.000284623481847041),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='id4'),
#                  namespace(qubits=[0],
#                            gate='rz',
#                            parameters=[Nduv('2021-01-15T00:39:29Z', gate_error, , 0),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 0)],
#                            name='rz0'),
#                  namespace(qubits=[1],
#                            gate='rz',
#                            parameters=[Nduv('2021-01-15T00:39:29Z', gate_error, , 0),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 0)],
#                            name='rz1'),
#                  namespace(qubits=[2],
#                            gate='rz',
#                            parameters=[Nduv('2021-01-15T00:39:29Z', gate_error, , 0),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 0)],
#                            name='rz2'),
#                  namespace(qubits=[3],
#                            gate='rz',
#                            parameters=[Nduv('2021-01-15T00:39:29Z', gate_error, , 0),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 0)],
#                            name='rz3'),
#                  namespace(qubits=[4],
#                            gate='rz',
#                            parameters=[Nduv('2021-01-15T00:39:29Z', gate_error, , 0),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 0)],
#                            name='rz4'),
#                  namespace(qubits=[0],
#                            gate='sx',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.00034156839459650943),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='sx0'),
#                  namespace(qubits=[1],
#                            gate='sx',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0005482093355872214),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='sx1'),
#                  namespace(qubits=[2],
#                            gate='sx',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0002868519954136414),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='sx2'),
#                  namespace(qubits=[3],
#                            gate='sx',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0022604510006537376),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='sx3'),
#                  namespace(qubits=[4],
#                            gate='sx',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.000284623481847041),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='sx4'),
#                  namespace(qubits=[0],
#                            gate='x',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.00034156839459650943),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='x0'),
#                  namespace(qubits=[1],
#                            gate='x',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0005482093355872214),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='x1'),
#                  namespace(qubits=[2],
#                            gate='x',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0002868519954136414),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='x2'),
#                  namespace(qubits=[3],
#                            gate='x',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.0022604510006537376),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='x3'),
#                  namespace(qubits=[4],
#                            gate='x',
#                            parameters=[Nduv('2021-01-14T05:28:15Z', gate_error, , 0.000284623481847041),
#                                        Nduv('2021-01-15T00:39:29Z', gate_length, ns, 35.55555555555556)],
#                            name='x4'),
#                  namespace(qubits=[4, 3],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:52:24Z', gate_error, , 0.00829095569472113),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 384)],
#                            name='cx4_3'),
#                  namespace(qubits=[3, 4],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:52:24Z', gate_error, , 0.00829095569472113),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 419.55555555555554)],
#                            name='cx3_4'),
#                  namespace(qubits=[2, 3],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:46:35Z', gate_error, , 0.012778958119016803),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 284.44444444444446)],
#                            name='cx2_3'),
#                  namespace(qubits=[3, 2],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:46:35Z', gate_error, , 0.012778958119016803),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 320)],
#                            name='cx3_2'),
#                  namespace(qubits=[1, 2],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:42:15Z', gate_error, , 0.012642816987186195),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 270.22222222222223)],
#                            name='cx1_2'),
#                  namespace(qubits=[2, 1],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:42:15Z', gate_error, , 0.012642816987186195),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 305.77777777777777)],
#                            name='cx2_1'),
#                  namespace(qubits=[1, 0],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:34:07Z', gate_error, , 0.038398228998808154),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 376.88888888888886)],
#                            name='cx1_0'),
#                  namespace(qubits=[0, 1],
#                            gate='cx',
#                            parameters=[Nduv('2021-01-14T05:34:07Z', gate_error, , 0.038398228998808154),
#                                        Nduv('2021-01-12T00:39:29Z', gate_length, ns, 412.4444444444444)],
#                            name='cx0_1')],
#           _qubits={0: {'T1': (6.995674882255299e-05, '2021-01-14T05:24:47Z'),
#                     'T2': (0.0001240954622256197, '2021-01-14T05:25:53Z'),
#                     'frequency': (5175370551.168444, '2021-01-15T00:39:29Z'),
#                     'anharmonicity': (-336102370.5583405,
#                      '2021-01-15T00:39:29Z'),
#                     'readout_error': (0.010599999999999943,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas0_prep1': (0.013599999999999945,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas1_prep0': (0.0076, '2021-01-14T05:23:45Z'),
#                     'readout_length': (3.3528888888888887e-06,
#                      '2021-01-14T05:23:45Z')},
#                    1: {'T1': (6.035978891919181e-05, '2021-01-14T05:24:47Z'),
#                     'T2': (9.109046874520748e-05, '2021-01-14T05:27:09Z'),
#                     'frequency': (5267221087.060701, '2021-01-15T00:39:29Z'),
#                     'anharmonicity': (-332545044.12181485,
#                      '2021-01-15T00:39:29Z'),
#                     'readout_error': (0.011200000000000099,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas0_prep1': (0.015800000000000036,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas1_prep0': (0.0066, '2021-01-14T05:23:45Z'),
#                     'readout_length': (3.3528888888888887e-06,
#                      '2021-01-14T05:23:45Z')},
#                    2: {'T1': (0.00012917029316574487, '2021-01-13T05:10:56Z'),
#                     'T2': (0.0001275411538956816, '2021-01-14T05:25:53Z'),
#                     'frequency': (5052377908.692426, '2021-01-15T00:39:29Z'),
#                     'anharmonicity': (-337077177.19017226,
#                      '2021-01-15T00:39:29Z'),
#                     'readout_error': (0.027700000000000058,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas0_prep1': (0.04200000000000004,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas1_prep0': (0.0134, '2021-01-14T05:23:45Z'),
#                     'readout_length': (3.3528888888888887e-06,
#                      '2021-01-14T05:23:45Z')},
#                    3: {'T1': (0.00011812077036952731, '2021-01-14T05:24:47Z'),
#                     'T2': (2.5075469693908007e-05, '2021-01-13T05:13:14Z'),
#                     'frequency': (4855992402.6836815, '2021-01-15T00:39:29Z'),
#                     'anharmonicity': (-324835961.91153777,
#                      '2021-01-15T00:39:29Z'),
#                     'readout_error': (0.1481, '2021-01-14T05:23:45Z'),
#                     'prob_meas0_prep1': (0.16759999999999997,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas1_prep0': (0.1286, '2021-01-14T05:23:45Z'),
#                     'readout_length': (3.3528888888888887e-06,
#                      '2021-01-14T05:23:45Z')},
#                    4: {'T1': (6.802993923909345e-05, '2021-01-14T05:24:47Z'),
#                     'T2': (0.00014149854564701666, '2021-01-14T05:25:53Z'),
#                     'frequency': (5118555163.97272, '2021-01-15T00:39:29Z'),
#                     'anharmonicity': (-336133418.52187276,
#                      '2021-01-15T00:39:29Z'),
#                     'readout_error': (0.019200000000000106,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas0_prep1': (0.027800000000000047,
#                      '2021-01-14T05:23:45Z'),
#                     'prob_meas1_prep0': (0.0106, '2021-01-14T05:23:45Z'),
#                     'readout_length': (3.3528888888888887e-06,
#                      '2021-01-14T05:23:45Z')}},
#           _gates={'id': {(0,): {'gate_error': (0.00034156839459650943,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (1,): {'gate_error': (0.0005482093355872214,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (2,): {'gate_error': (0.0002868519954136414,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (3,): {'gate_error': (0.0022604510006537376,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (4,): {'gate_error': (0.000284623481847041,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')}},
#                   'rz': {(0,): {'gate_error': (0, '2021-01-15T00:39:29Z'),
#                     'gate_length': (0.0, '2021-01-15T00:39:29Z')},
#                    (1,): {'gate_error': (0, '2021-01-15T00:39:29Z'),
#                     'gate_length': (0.0, '2021-01-15T00:39:29Z')},
#                    (2,): {'gate_error': (0, '2021-01-15T00:39:29Z'),
#                     'gate_length': (0.0, '2021-01-15T00:39:29Z')},
#                    (3,): {'gate_error': (0, '2021-01-15T00:39:29Z'),
#                     'gate_length': (0.0, '2021-01-15T00:39:29Z')},
#                    (4,): {'gate_error': (0, '2021-01-15T00:39:29Z'),
#                     'gate_length': (0.0, '2021-01-15T00:39:29Z')}},
#                   'sx': {(0,): {'gate_error': (0.00034156839459650943,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (1,): {'gate_error': (0.0005482093355872214,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (2,): {'gate_error': (0.0002868519954136414,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (3,): {'gate_error': (0.0022604510006537376,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (4,): {'gate_error': (0.000284623481847041,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')}},
#                   'x': {(0,): {'gate_error': (0.00034156839459650943,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (1,): {'gate_error': (0.0005482093355872214,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (2,): {'gate_error': (0.0002868519954136414,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (3,): {'gate_error': (0.0022604510006537376,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')},
#                    (4,): {'gate_error': (0.000284623481847041,
#                      '2021-01-14T05:28:15Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-01-15T00:39:29Z')}},
#                   'cx': {(4,
#                     3): {'gate_error': (0.00829095569472113,
#                      '2021-01-14T05:52:24Z'), 'gate_length': (3.8400000000000005e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (3,
#                     4): {'gate_error': (0.00829095569472113,
#                      '2021-01-14T05:52:24Z'), 'gate_length': (4.1955555555555557e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (2,
#                     3): {'gate_error': (0.012778958119016803,
#                      '2021-01-14T05:46:35Z'), 'gate_length': (2.844444444444445e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (3,
#                     2): {'gate_error': (0.012778958119016803,
#                      '2021-01-14T05:46:35Z'), 'gate_length': (3.2e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (1,
#                     2): {'gate_error': (0.012642816987186195,
#                      '2021-01-14T05:42:15Z'), 'gate_length': (2.702222222222222e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (2,
#                     1): {'gate_error': (0.012642816987186195,
#                      '2021-01-14T05:42:15Z'), 'gate_length': (3.057777777777778e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (1,
#                     0): {'gate_error': (0.038398228998808154,
#                      '2021-01-14T05:34:07Z'), 'gate_length': (3.768888888888889e-07,
#                      '2021-01-12T00:39:29Z')},
#                    (0,
#                     1): {'gate_error': (0.038398228998808154,
#                      '2021-01-14T05:34:07Z'), 'gate_length': (4.124444444444444e-07,
#                      '2021-01-12T00:39:29Z')}}})

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 3.555555555555556e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-5-9b35b1d1e556> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_length(self, gate, qubits)
#     341         """
#     342         return self.gate_property(gate, qubits,
# --> 343                                   'gate_length')[0]  # Throw away datetime at index 1
#     344
#     345     def qubit_property(self,
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     312                                                                                      g=gate))
#     313         except KeyError:
# --> 314             raise BackendPropertyError("Could not find the desired property for {g}".format(g=gate))
#     315         return result
#     316
#
# BackendPropertyError: 'Could not find the desired property for u2'

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_armonk')
prop=backend.properties()
for i in range(0,1):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 4.9777777777777776e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-6-0a345a4881a2> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_length(self, gate, qubits)
#     341         """
#     342         return self.gate_property(gate, qubits,
# --> 343                                   'gate_length')[0]  # Throw away datetime at index 1
#     344
#     345     def qubit_property(self,
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     312                                                                                      g=gate))
#     313         except KeyError:
# --> 314             raise BackendPropertyError("Could not find the desired property for {g}".format(g=gate))
#     315         return result
#     316
#
# BackendPropertyError: 'Could not find the desired property for u2'

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmqx2')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_santiago')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_vigo')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_ourense')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
#ibmq_valencia
backends = provider.backends()

backend = provider.get_backend('ibmq_valencia')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
