# %%
from qiskit import IBMQ
IBMQ.disable_account() 

token0 = '21a7ae9539b78959e11dcc1383c5691767f36b13d5d8efa01e515b76714b796903c19a61537adf98583e1cb04e4ee2584c6ba5f632b9a16cb8ad80cc6ce90ba7'
provider = IBMQ.enable_account(token0)

# %% [markdown]
# ## check job complete time

# %%
job_id = '60d6485b9cbb5780b2f34581'
backend = provider.backends
job = backend.retrieve_job(job_id)
job._time_per_step['COMPLETED']
# Out:
# '2021-06-25T21:43:23.445Z'

# %%
job
# Out:
# namespace(_backend=<IBMQRetiredBackend('ibmq_athens') from IBMQ(hub='ibm-q', group='open', project='main')>,
#           _api=<qiskit.providers.ibmq.api.clients.account.AccountClient at 0x7f85729b1e50>,
#           _job_id='60d6485b9cbb5780b2f34581',
#           _creation_date=datetime.datetime(2021, 6, 25, 21, 19, 23, 332000, tzinfo=tzutc()),
#           _api_status='COMPLETED',
#           _kind=<ApiJobKind.QOBJECT_STORAGE: 'q-object-external-storage'>,
#           _name=None,
#           _time_per_step={'CREATING': '2021-06-25T21:19:23.332Z',
#                           'CREATED': '2021-06-25T21:19:26.668Z',
#                           'VALIDATING': '2021-06-25T21:19:26.698Z',
#                           'VALIDATED': '2021-06-25T21:20:39.832Z',
#                           'QUEUED': '2021-06-25T21:20:39.996Z',
#                           'RUNNING': '2021-06-25T21:38:03.049Z',
#                           'COMPLETED': '2021-06-25T21:43:23.445Z'},
#           _result=None,
#           _qobj=None,
#           _error=None,
#           _tags=[],
#           _run_mode='fairshare',
#           _status=<JobStatus.DONE: 'job has successfully run'>,
#           _queue_info=None,
#           _use_object_storage=True,
#           _backend_info={'id': '5e7ca123ef0935c3e8d138b7',
#                          'name': 'ibmq_athens'},
#           object_storage_info={},
#           deleted=False,
#           allow_object_storage=True,
#           summary_data={'size': {'input': 24254690, 'output': 27932},
#                         'success': True,
#                         'summary': {'num_circuits': 74,
#                          'gates_executed': 596570,
#                          'max_qubits_used': 5,
#                          'qobj_config': {'cost': 188.20228571428572,
#                           'shots': 8192,
#                           'memory_slots': 5,
#                           'type': 'QASM',
#                           'n_qubits': 5},
#                          'partial_validation': False},
#                         'resultTime': 319.95680615492165},
#           hub_info={'hub': {'name': 'ibm-q'},
#                     'group': {'name': 'open'},
#                     'project': {'name': 'main'}},
#           end_date='2021-06-25T21:43:23.168Z',
#           cost=188.20228571428572,
#           share_level='none',
#           user_id='5dd1f42ce9ff2500185fe478',
#           live_data_enabled=False,
#           created_by='local',
#           client_info={'name': 'ibmqprovider', 'version': '0.7.0'},
#           _cancelled=False,
#           _job_error_msg=None)

# %%
provider.backends.jobs(backend_name='ibmq_athens')[9].properties()
# Out:
# namespace(backend_name='ibmq_athens',
#           backend_version='1.3.21',
#           last_update_date=datetime.datetime(2021, 7, 2, 15, 44, 43, tzinfo=tzutc()),
#           general=[Nduv('2021-07-02T15:44:43Z', jq_01, GHz, 0.00167045114712927),
#                    Nduv('2021-07-02T15:44:43Z', zz_01, GHz, -3.802523473566748e-05),
#                    Nduv('2021-07-02T15:44:43Z', jq_12, GHz, 0.001715963318618043),
#                    Nduv('2021-07-02T15:44:43Z', zz_12, GHz, -6.739337717569015e-05),
#                    Nduv('2021-07-02T15:44:43Z', jq_23, GHz, 0.001419786134211377),
#                    Nduv('2021-07-02T15:44:43Z', zz_23, GHz, -4.029010458592919e-05),
#                    Nduv('2021-07-02T15:44:43Z', jq_34, GHz, 0.0014300376658986506),
#                    Nduv('2021-07-02T15:44:43Z', zz_34, GHz, -7.676209360402695e-05)],
#           qubits=[[Nduv('2021-07-02T15:31:39Z', T1, us, 84.47146992675015),
#                    Nduv('2021-07-02T04:06:41Z', T2, us, 84.30719725565304),
#                    Nduv('2021-07-02T15:44:43Z', frequency, GHz, 5.175385520911228),
#                    Nduv('2021-07-02T15:44:43Z', anharmonicity, GHz, -0.33610237055834047),
#                    Nduv('2021-07-02T04:05:07Z', readout_error, , 0.009400000000000075),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas0_prep1, , 0.015199999999999991),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas1_prep0, , 0.0036),
#                    Nduv('2021-07-02T04:05:07Z', readout_length, ns, 3022.222222222222)],
#                   [Nduv('2021-07-02T09:16:45Z', T1, us, 90.03341440399076),
#                    Nduv('2021-07-02T04:09:10Z', T2, us, 139.53874532742304),
#                    Nduv('2021-07-02T15:44:43Z', frequency, GHz, 5.2672155923365676),
#                    Nduv('2021-07-02T15:44:43Z', anharmonicity, GHz, -0.33254504412181485),
#                    Nduv('2021-07-02T04:05:07Z', readout_error, , 0.013800000000000034),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas0_prep1, , 0.02400000000000002),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas1_prep0, , 0.0036),
#                    Nduv('2021-07-02T04:05:07Z', readout_length, ns, 3022.222222222222)],
#                   [Nduv('2021-07-02T15:31:39Z', T1, us, 71.63407947946672),
#                    Nduv('2021-07-02T04:06:41Z', T2, us, 133.00566384040175),
#                    Nduv('2021-07-02T15:44:43Z', frequency, GHz, 5.052429633874489),
#                    Nduv('2021-07-02T15:44:43Z', anharmonicity, GHz, -0.3370771771901723),
#                    Nduv('2021-07-02T04:05:07Z', readout_error, , 0.018000000000000016),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas0_prep1, , 0.02639999999999998),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas1_prep0, , 0.0096),
#                    Nduv('2021-07-02T04:05:07Z', readout_length, ns, 3022.222222222222)],
#                   [Nduv('2021-07-02T09:16:45Z', T1, us, 83.82414094860839),
#                    Nduv('2021-07-02T04:09:10Z', T2, us, 28.31701876495526),
#                    Nduv('2021-07-02T15:44:43Z', frequency, GHz, 4.855930925896754),
#                    Nduv('2021-07-02T15:44:43Z', anharmonicity, GHz, -0.32483596191153774),
#                    Nduv('2021-07-02T04:05:07Z', readout_error, , 0.015700000000000047),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas0_prep1, , 0.02639999999999998),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas1_prep0, , 0.005),
#                    Nduv('2021-07-02T04:05:07Z', readout_length, ns, 3022.222222222222)],
#                   [Nduv('2021-07-02T15:31:39Z', T1, us, 82.3998533487433),
#                    Nduv('2021-07-02T04:06:41Z', T2, us, 133.57649284933208),
#                    Nduv('2021-07-02T15:44:43Z', frequency, GHz, 5.11852510480996),
#                    Nduv('2021-07-02T15:44:43Z', anharmonicity, GHz, -0.3361334185218728),
#                    Nduv('2021-07-02T04:05:07Z', readout_error, , 0.01200000000000001),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas0_prep1, , 0.017199999999999993),
#                    Nduv('2021-07-02T04:05:07Z', prob_meas1_prep0, , 0.0068),
#                    Nduv('2021-07-02T04:05:07Z', readout_length, ns, 3022.222222222222)]],
#           gates=[namespace(qubits=[0],
#                            gate='id',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00034043547256014535),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='id0'),
#                  namespace(qubits=[1],
#                            gate='id',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0002794436592663849),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='id1'),
#                  namespace(qubits=[2],
#                            gate='id',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0013044244337345023),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='id2'),
#                  namespace(qubits=[3],
#                            gate='id',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00026878451262036217),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='id3'),
#                  namespace(qubits=[4],
#                            gate='id',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00019838743264756674),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='id4'),
#                  namespace(qubits=[0],
#                            gate='rz',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_error, , 0),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 0)],
#                            name='rz0'),
#                  namespace(qubits=[1],
#                            gate='rz',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_error, , 0),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 0)],
#                            name='rz1'),
#                  namespace(qubits=[2],
#                            gate='rz',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_error, , 0),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 0)],
#                            name='rz2'),
#                  namespace(qubits=[3],
#                            gate='rz',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_error, , 0),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 0)],
#                            name='rz3'),
#                  namespace(qubits=[4],
#                            gate='rz',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_error, , 0),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 0)],
#                            name='rz4'),
#                  namespace(qubits=[0],
#                            gate='sx',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00034043547256014535),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='sx0'),
#                  namespace(qubits=[1],
#                            gate='sx',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0002794436592663849),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='sx1'),
#                  namespace(qubits=[2],
#                            gate='sx',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0013044244337345023),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='sx2'),
#                  namespace(qubits=[3],
#                            gate='sx',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00026878451262036217),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='sx3'),
#                  namespace(qubits=[4],
#                            gate='sx',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00019838743264756674),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='sx4'),
#                  namespace(qubits=[0],
#                            gate='x',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00034043547256014535),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='x0'),
#                  namespace(qubits=[1],
#                            gate='x',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0002794436592663849),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='x1'),
#                  namespace(qubits=[2],
#                            gate='x',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.0013044244337345023),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='x2'),
#                  namespace(qubits=[3],
#                            gate='x',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00026878451262036217),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='x3'),
#                  namespace(qubits=[4],
#                            gate='x',
#                            parameters=[Nduv('2021-07-02T04:10:45Z', gate_error, , 0.00019838743264756674),
#                                        Nduv('2021-07-02T15:44:43Z', gate_length, ns, 35.55555555555556)],
#                            name='x4'),
#                  namespace(qubits=[4, 3],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:23:55Z', gate_error, , 0.006928906820278746),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 384)],
#                            name='cx4_3'),
#                  namespace(qubits=[3, 4],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:23:55Z', gate_error, , 0.006928906820278746),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 419.55555555555554)],
#                            name='cx3_4'),
#                  namespace(qubits=[2, 3],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:21:19Z', gate_error, , 0.013687741408812515),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 284.44444444444446)],
#                            name='cx2_3'),
#                  namespace(qubits=[3, 2],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:21:19Z', gate_error, , 0.013687741408812515),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 320)],
#                            name='cx3_2'),
#                  namespace(qubits=[1, 2],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:18:33Z', gate_error, , 0.014812372312797834),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 270.22222222222223)],
#                            name='cx1_2'),
#                  namespace(qubits=[2, 1],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:18:33Z', gate_error, , 0.014812372312797834),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 305.77777777777777)],
#                            name='cx2_1'),
#                  namespace(qubits=[1, 0],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:15:50Z', gate_error, , 0.009199416998416948),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 376.88888888888886)],
#                            name='cx1_0'),
#                  namespace(qubits=[0, 1],
#                            gate='cx',
#                            parameters=[Nduv('2021-07-02T04:15:50Z', gate_error, , 0.009199416998416948),
#                                        Nduv('2021-06-29T15:44:43Z', gate_length, ns, 412.4444444444444)],
#                            name='cx0_1'),
#                  namespace(qubits=[0],
#                            gate='reset',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_length, ns, 3431.111111111111)],
#                            name='reset0'),
#                  namespace(qubits=[1],
#                            gate='reset',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_length, ns, 3431.111111111111)],
#                            name='reset1'),
#                  namespace(qubits=[2],
#                            gate='reset',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_length, ns, 3431.111111111111)],
#                            name='reset2'),
#                  namespace(qubits=[3],
#                            gate='reset',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_length, ns, 3431.111111111111)],
#                            name='reset3'),
#                  namespace(qubits=[4],
#                            gate='reset',
#                            parameters=[Nduv('2021-07-02T15:44:43Z', gate_length, ns, 3431.111111111111)],
#                            name='reset4')],
#           _qubits={0: {'T1': (8.447146992675014e-05, '2021-07-02T15:31:39Z'),
#                     'T2': (8.430719725565303e-05, '2021-07-02T04:06:41Z'),
#                     'frequency': (5175385520.911228, '2021-07-02T15:44:43Z'),
#                     'anharmonicity': (-336102370.5583405,
#                      '2021-07-02T15:44:43Z'),
#                     'readout_error': (0.009400000000000075,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas0_prep1': (0.015199999999999991,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas1_prep0': (0.0036, '2021-07-02T04:05:07Z'),
#                     'readout_length': (3.0222222222222225e-06,
#                      '2021-07-02T04:05:07Z')},
#                    1: {'T1': (9.003341440399076e-05, '2021-07-02T09:16:45Z'),
#                     'T2': (0.00013953874532742305, '2021-07-02T04:09:10Z'),
#                     'frequency': (5267215592.336568, '2021-07-02T15:44:43Z'),
#                     'anharmonicity': (-332545044.12181485,
#                      '2021-07-02T15:44:43Z'),
#                     'readout_error': (0.013800000000000034,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas0_prep1': (0.02400000000000002,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas1_prep0': (0.0036, '2021-07-02T04:05:07Z'),
#                     'readout_length': (3.0222222222222225e-06,
#                      '2021-07-02T04:05:07Z')},
#                    2: {'T1': (7.163407947946672e-05, '2021-07-02T15:31:39Z'),
#                     'T2': (0.00013300566384040173, '2021-07-02T04:06:41Z'),
#                     'frequency': (5052429633.874489, '2021-07-02T15:44:43Z'),
#                     'anharmonicity': (-337077177.19017226,
#                      '2021-07-02T15:44:43Z'),
#                     'readout_error': (0.018000000000000016,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas0_prep1': (0.02639999999999998,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas1_prep0': (0.0096, '2021-07-02T04:05:07Z'),
#                     'readout_length': (3.0222222222222225e-06,
#                      '2021-07-02T04:05:07Z')},
#                    3: {'T1': (8.382414094860838e-05, '2021-07-02T09:16:45Z'),
#                     'T2': (2.831701876495526e-05, '2021-07-02T04:09:10Z'),
#                     'frequency': (4855930925.896754, '2021-07-02T15:44:43Z'),
#                     'anharmonicity': (-324835961.91153777,
#                      '2021-07-02T15:44:43Z'),
#                     'readout_error': (0.015700000000000047,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas0_prep1': (0.02639999999999998,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas1_prep0': (0.005, '2021-07-02T04:05:07Z'),
#                     'readout_length': (3.0222222222222225e-06,
#                      '2021-07-02T04:05:07Z')},
#                    4: {'T1': (8.239985334874331e-05, '2021-07-02T15:31:39Z'),
#                     'T2': (0.0001335764928493321, '2021-07-02T04:06:41Z'),
#                     'frequency': (5118525104.809959, '2021-07-02T15:44:43Z'),
#                     'anharmonicity': (-336133418.52187276,
#                      '2021-07-02T15:44:43Z'),
#                     'readout_error': (0.01200000000000001,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas0_prep1': (0.017199999999999993,
#                      '2021-07-02T04:05:07Z'),
#                     'prob_meas1_prep0': (0.0068, '2021-07-02T04:05:07Z'),
#                     'readout_length': (3.0222222222222225e-06,
#                      '2021-07-02T04:05:07Z')}},
#           _gates={'id': {(0,): {'gate_error': (0.00034043547256014535,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (1,): {'gate_error': (0.0002794436592663849,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (2,): {'gate_error': (0.0013044244337345023,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (3,): {'gate_error': (0.00026878451262036217,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (4,): {'gate_error': (0.00019838743264756674,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')}},
#                   'rz': {(0,): {'gate_error': (0, '2021-07-02T15:44:43Z'),
#                     'gate_length': (0.0, '2021-07-02T15:44:43Z')},
#                    (1,): {'gate_error': (0, '2021-07-02T15:44:43Z'),
#                     'gate_length': (0.0, '2021-07-02T15:44:43Z')},
#                    (2,): {'gate_error': (0, '2021-07-02T15:44:43Z'),
#                     'gate_length': (0.0, '2021-07-02T15:44:43Z')},
#                    (3,): {'gate_error': (0, '2021-07-02T15:44:43Z'),
#                     'gate_length': (0.0, '2021-07-02T15:44:43Z')},
#                    (4,): {'gate_error': (0, '2021-07-02T15:44:43Z'),
#                     'gate_length': (0.0, '2021-07-02T15:44:43Z')}},
#                   'sx': {(0,): {'gate_error': (0.00034043547256014535,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (1,): {'gate_error': (0.0002794436592663849,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (2,): {'gate_error': (0.0013044244337345023,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (3,): {'gate_error': (0.00026878451262036217,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (4,): {'gate_error': (0.00019838743264756674,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')}},
#                   'x': {(0,): {'gate_error': (0.00034043547256014535,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (1,): {'gate_error': (0.0002794436592663849,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (2,): {'gate_error': (0.0013044244337345023,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (3,): {'gate_error': (0.00026878451262036217,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')},
#                    (4,): {'gate_error': (0.00019838743264756674,
#                      '2021-07-02T04:10:45Z'),
#                     'gate_length': (3.555555555555556e-08,
#                      '2021-07-02T15:44:43Z')}},
#                   'cx': {(4,
#                     3): {'gate_error': (0.006928906820278746,
#                      '2021-07-02T04:23:55Z'), 'gate_length': (3.8400000000000005e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (3,
#                     4): {'gate_error': (0.006928906820278746,
#                      '2021-07-02T04:23:55Z'), 'gate_length': (4.1955555555555557e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (2,
#                     3): {'gate_error': (0.013687741408812515,
#                      '2021-07-02T04:21:19Z'), 'gate_length': (2.844444444444445e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (3,
#                     2): {'gate_error': (0.013687741408812515,
#                      '2021-07-02T04:21:19Z'), 'gate_length': (3.2e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (1,
#                     2): {'gate_error': (0.014812372312797834,
#                      '2021-07-02T04:18:33Z'), 'gate_length': (2.702222222222222e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (2,
#                     1): {'gate_error': (0.014812372312797834,
#                      '2021-07-02T04:18:33Z'), 'gate_length': (3.057777777777778e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (1,
#                     0): {'gate_error': (0.009199416998416948,
#                      '2021-07-02T04:15:50Z'), 'gate_length': (3.768888888888889e-07,
#                      '2021-06-29T15:44:43Z')},
#                    (0,
#                     1): {'gate_error': (0.009199416998416948,
#                      '2021-07-02T04:15:50Z'), 'gate_length': (4.124444444444444e-07,
#                      '2021-06-29T15:44:43Z')}},
#                   'reset': {(0,): {'gate_length': (3.431111111111111e-06,
#                      '2021-07-02T15:44:43Z')},
#                    (1,): {'gate_length': (3.431111111111111e-06,
#                      '2021-07-02T15:44:43Z')},
#                    (2,): {'gate_length': (3.431111111111111e-06,
#                      '2021-07-02T15:44:43Z')},
#                    (3,): {'gate_length': (3.431111111111111e-06,
#                      '2021-07-02T15:44:43Z')},
#                    (4,): {'gate_length': (3.431111111111111e-06,
#                      '2021-07-02T15:44:43Z')}}})

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 3.555555555555556e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-5-9b35b1d1e556> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_length(self, gate, qubits)
#     341         """
#     342         return self.gate_property(gate, qubits,
# --> 343                                   'gate_length')[0]  # Throw away datetime at index 1
#     344
#     345     def qubit_property(self,
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     312                                                                                      g=gate))
#     313         except KeyError:
# --> 314             raise BackendPropertyError("Could not find the desired property for {g}".format(g=gate))
#     315         return result
#     316
#
# BackendPropertyError: 'Could not find the desired property for u2'

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_armonk')
prop=backend.properties()
for i in range(0,1):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
# Out:
# qubit:  0
# id 4.9777777777777776e-08
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     302         try:
# --> 303             result = self._gates[gate]
#     304             if qubits is not None:
#
# KeyError: 'u2'
#
# During handling of the above exception, another exception occurred:
#
# BackendPropertyError                      Traceback (most recent call last)
# <ipython-input-6-0a345a4881a2> in <module>
#       6     print('qubit: ',i)
#       7     print('id', prop.gate_length('id',i))
# ----> 8     print('u2',prop.gate_length('u2',i))
#       9     print('u3',prop.gate_length('u3',i))
#      10     print('t1 ',prop.t1(i))
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_length(self, gate, qubits)
#     341         """
#     342         return self.gate_property(gate, qubits,
# --> 343                                   'gate_length')[0]  # Throw away datetime at index 1
#     344
#     345     def qubit_property(self,
#
# ~/anaconda3/envs/IBM_scheduler/lib/python3.7/site-packages/qiskit/providers/models/backendproperties.py in gate_property(self, gate, qubits, name)
#     312                                                                                      g=gate))
#     313         except KeyError:
# --> 314             raise BackendPropertyError("Could not find the desired property for {g}".format(g=gate))
#     315         return result
#     316
#
# BackendPropertyError: 'Could not find the desired property for u2'

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_athens')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmqx2')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_santiago')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_vigo')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
backends = provider.backends()

backend = provider.get_backend('ibmq_ourense')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))

# %%
#ibmq_valencia
backends = provider.backends()

backend = provider.get_backend('ibmq_valencia')
prop=backend.properties()
for i in range(0,5):
    print('qubit: ',i)
    print('id', prop.gate_length('id',i))
    print('u2',prop.gate_length('u2',i))
    print('u3',prop.gate_length('u3',i))
    print('t1 ',prop.t1(i))
    print('t2 ',prop.t2(i))
